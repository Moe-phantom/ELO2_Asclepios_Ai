# %% [markdown]
# ## Load Data and Analyze Missing Patterns
# Examine extent and patterns of missing data

# %%
import pandas as pd

df = pd.read_csv("1_datasets/processed/teds_a_2023_cleaned.csv")
# Out:
# C:\Users\YNA\AppData\Local\Temp\ipykernel_5828\4223267905.py:3: DtypeWarning: Columns (5,6,8,9,12,13,14,17,23,24,25,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("1_datasets/processed/teds_a_2023_cleaned.csv")

# %% [markdown]
# ## Calculate Missing Value Statistics
# Get percentage of missing values for each column

# %%
missing_stats = pd.DataFrame(
    {
        "column": df.columns,
        "missing_count": df.isnull().sum(),
        "missing_percent": (df.isnull().sum() / len(df) * 100).round(2),
        "non_missing_count": df.notnull().sum(),
    }
).sort_values("missing_percent", ascending=False)
missing_stats
# Out:
#                                                       column  missing_count  \
# recent_arrests                                recent_arrests        1528810
# tertiary_substance                        tertiary_substance        1390965
# pregnant                                            pregnant        1131055
# income_source                                  income_source         962960
# secondary_substance                      secondary_substance         957190
# health_insurance                            health_insurance         878480
# wait_time_days                                wait_time_days         872723
# payment_source                                payment_source         867697
# marital_status                                marital_status         474164
# self_help_attendance                    self_help_attendance         443359
# years_using                                      years_using         412027
# age_first_use_primary                  age_first_use_primary         412027
# frequency_primary                          frequency_primary         377464
# route_primary                                  route_primary         371466
# living_arrangement                        living_arrangement         363717
# primary_substance                          primary_substance         355418
# substance_category                        substance_category         355418
# injection_drug_use                        injection_drug_use         355388
# education_level                              education_level         340515
# referral_source                              referral_source         334032
# dsm_diagnosis                                  dsm_diagnosis         323974
# veteran_status                                veteran_status         313242
# employment_status                          employment_status         270220
# has_cooccurring_mental_health  has_cooccurring_mental_health         229682
# prior_treatments                            prior_treatments         186956
# medication_assisted_therapy      medication_assisted_therapy         181777
# ethnicity                                          ethnicity         165520
# race                                                    race         114082
# sex                                                      sex           1227
# patient_id                                        patient_id              0
# service_type                                    service_type              0
# age_group                                          age_group              0
# region                                                region              0
# state                                                  state              0
# number_of_substances                    number_of_substances              0
# is_polysubstance                            is_polysubstance              0
# is_stimulant_primary                    is_stimulant_primary              0
# is_opioid_primary                          is_opioid_primary              0
# is_criminal_justice_referral    is_criminal_justice_referral              0
# has_recent_arrest                          has_recent_arrest              0
# is_chronic_treatment                    is_chronic_treatment              0
# is_injection_user                          is_injection_user              0
# is_first_treatment                        is_first_treatment              0
# has_long_wait                                  has_long_wait              0
# is_older_adult                                is_older_adult              0
# is_adolescent                                  is_adolescent              0
# is_pregnant                                      is_pregnant              0
# is_homeless                                      is_homeless              0
# has_no_income                                  has_no_income              0
# has_mental_health_disorder        has_mental_health_disorder              0
#
#                                missing_percent  non_missing_count
# recent_arrests                           94.03              97023
# tertiary_substance                       85.55             234868
# pregnant                                 69.57             494778
# income_source                            59.23             662873
# secondary_substance                      58.87             668643
# health_insurance                         54.03             747353
# wait_time_days                           53.68             753110
# payment_source                           53.37             758136
# marital_status                           29.16            1151669
# self_help_attendance                     27.27            1182474
# years_using                              25.34            1213806
# age_first_use_primary                    25.34            1213806
# frequency_primary                        23.22            1248369
# route_primary                            22.85            1254367
# living_arrangement                       22.37            1262116
# primary_substance                        21.86            1270415
# substance_category                       21.86            1270415
# injection_drug_use                       21.86            1270445
# education_level                          20.94            1285318
# referral_source                          20.55            1291801
# dsm_diagnosis                            19.93            1301859
# veteran_status                           19.27            1312591
# employment_status                        16.62            1355613
# has_cooccurring_mental_health            14.13            1396151
# prior_treatments                         11.50            1438877
# medication_assisted_therapy              11.18            1444056
# ethnicity                                10.18            1460313
# race                                      7.02            1511751
# sex                                       0.08            1624606
# patient_id                                0.00            1625833
# service_type                              0.00            1625833
# age_group                                 0.00            1625833
# region                                    0.00            1625833
# state                                     0.00            1625833
# number_of_substances                      0.00            1625833
# is_polysubstance                          0.00            1625833
# is_stimulant_primary                      0.00            1625833
# is_opioid_primary                         0.00            1625833
# is_criminal_justice_referral              0.00            1625833
# has_recent_arrest                         0.00            1625833
# is_chronic_treatment                      0.00            1625833
# is_injection_user                         0.00            1625833
# is_first_treatment                        0.00            1625833
# has_long_wait                             0.00            1625833
# is_older_adult                            0.00            1625833
# is_adolescent                             0.00            1625833
# is_pregnant                               0.00            1625833
# is_homeless                               0.00            1625833
# has_no_income                             0.00            1625833
# has_mental_health_disorder                0.00            1625833

# %% [markdown]
# ## Identify Critical Variables
# Define which variables are essential (cannot be missing for analysis) and
# remove only rows missing critical variables for analysis

# %%
critical_vars = ["patient_id", "service_type", "primary_substance", "age_group", "sex"]

df_analysis = df.dropna(subset=critical_vars)

rows_removed = len(df) - len(df_analysis)
removal_percent = round((rows_removed / len(df) * 100), 2)

removal_summary = {
    "original_rows": len(df),
    "rows_after_removal": len(df_analysis),
    "rows_removed": rows_removed,
    "percent_removed": removal_percent,
}
df_analysis.to_csv("1_datasets/processed/teds_analysis_ready.csv", index=False)

# %% [markdown]
# ## Machine Learning Preparation (For Later Phase)
# For ML models, we'll need imputation rather than deletion

# %%
df_ml = df.copy()

numeric_cols = ["years_using", "number_of_substances"]
for col in numeric_cols:
    if col in df_ml.columns:
        df_ml[col] = df_ml[col].fillna(df_ml[col].median())

categorical_cols = [
    "wait_time_days",
    "prior_treatments",
    "employment_status",
    "education_level",
    "living_arrangement",
    "income_source",
]
for col in categorical_cols:
    if col in df_ml.columns:
        df_ml[col] = df_ml[col].fillna(df_ml[col].mode()[0])

binary_cols = [
    col for col in df_ml.columns if col.startswith("is_") or col.startswith("has_")
]
for col in binary_cols:
    if col in df_ml.columns:
        df_ml[col] = df_ml[col].fillna(0)

df_ml.to_csv("1_datasets/processed/teds_ml_ready.csv", index=False)
